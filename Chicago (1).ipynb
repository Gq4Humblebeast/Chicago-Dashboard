# %%
import pandas as pd
import numpy as np
import panel as pn
# !pip install hvplot
import hvplot.pandas  # noqa
pn.extension('tabulator')
# Out:
# Requirement already satisfied: hvplot in c:\users\laqua\appdata\local\programs\python\python312\lib\site-packages (0.10.0)
# Requirement already satisfied: bokeh>=1.0.0 in c:\users\laqua\appdata\local\programs\python\python312\lib\site-packages (from hvplot) (3.4.3)
# Requirement already satisfied: colorcet>=2 in c:\users\laqua\appdata\local\programs\python\python312\lib\site-packages (from hvplot) (3.1.0)
# Requirement already satisfied: holoviews>=1.11.0 in c:\users\laqua\appdata\local\programs\python\python312\lib\site-packages (from hvplot) (1.19.1)
# Requirement already satisfied: numpy>=1.15 in c:\users\laqua\appdata\local\programs\python\python312\lib\site-packages (from hvplot) (2.0.1)
# Requirement already satisfied: packaging in c:\users\laqua\appdata\local\programs\python\python312\lib\site-packages (from hvplot) (24.1)
# Requirement already satisfied: pandas in c:\users\laqua\appdata\local\programs\python\python312\lib\site-packages (from hvplot) (2.2.2)
# Requirement already satisfied: panel>=0.11.0 in c:\users\laqua\appdata\local\programs\python\python312\lib\site-packages (from hvplot) (1.4.5)
# Requirement already satisfied: param<3.0,>=1.12.0 in c:\users\laqua\appdata\local\programs\python\python312\lib\site-packages (from hvplot) (2.1.1)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\laqua\appdata\local\programs\python\python312\lib\site-packages (from bokeh>=1.0.0->hvplot) (3.1.4)
# Requirement already satisfied: contourpy>=1.2 in c:\users\laqua\appdata\local\programs\python\python312\lib\site-packages (from bokeh>=1.0.0->hvplot) (1.2.1)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\laqua\appdata\local\programs\python\python312\lib\site-packages (from bokeh>=1.0.0->hvplot) (10.4.0)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\laqua\appdata\local\programs\python\python312\lib\site-packages (from bokeh>=1.0.0->hvplot) (6.0.1)
# Requirement already satisfied: tornado>=6.2 in c:\users\laqua\appdata\local\programs\python\python312\lib\site-packages (from bokeh>=1.0.0->hvplot) (6.4.1)
# Requirement already satisfied: xyzservices>=2021.09.1 in c:\users\laqua\appdata\local\programs\python\python312\lib\site-packages (from bokeh>=1.0.0->hvplot) (2024.6.0)
# Requirement already satisfied: pyviz-comms>=2.1 in c:\users\laqua\appdata\local\programs\python\python312\lib\site-packages (from holoviews>=1.11.0->hvplot) (3.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\laqua\appdata\local\programs\python\python312\lib\site-packages (from pandas->hvplot) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\laqua\appdata\local\programs\python\python312\lib\site-packages (from pandas->hvplot) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\laqua\appdata\local\programs\python\python312\lib\site-packages (from pandas->hvplot) (2024.1)
# Requirement already satisfied: markdown in c:\users\laqua\appdata\local\programs\python\python312\lib\site-packages (from panel>=0.11.0->hvplot) (3.6)
# Requirement already satisfied: markdown-it-py in c:\users\laqua\appdata\local\programs\python\python312\lib\site-packages (from panel>=0.11.0->hvplot) (3.0.0)
# Requirement already satisfied: linkify-it-py in c:\users\laqua\appdata\local\programs\python\python312\lib\site-packages (from panel>=0.11.0->hvplot) (2.0.3)
# Requirement already satisfied: mdit-py-plugins in c:\users\laqua\appdata\local\programs\python\python312\lib\site-packages (from panel>=0.11.0->hvplot) (0.4.1)
# Requirement already satisfied: requests in c:\users\laqua\appdata\local\programs\python\python312\lib\site-packages (from panel>=0.11.0->hvplot) (2.32.3)
# Requirement already satisfied: tqdm>=4.48.0 in c:\users\laqua\appdata\local\programs\python\python312\lib\site-packages (from panel>=0.11.0->hvplot) (4.66.5)
# Requirement already satisfied: bleach in c:\users\laqua\appdata\local\programs\python\python312\lib\site-packages (from panel>=0.11.0->hvplot) (6.1.0)
# Requirement already satisfied: typing-extensions in c:\users\laqua\appdata\local\programs\python\python312\lib\site-packages (from panel>=0.11.0->hvplot) (4.12.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\laqua\appdata\local\programs\python\python312\lib\site-packages (from Jinja2>=2.9->bokeh>=1.0.0->hvplot) (2.1.5)
# Requirement already satisfied: six>=1.5 in c:\users\laqua\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas->hvplot) (1.16.0)
# Requirement already satisfied: colorama in c:\users\laqua\appdata\local\programs\python\python312\lib\site-packages (from tqdm>=4.48.0->panel>=0.11.0->hvplot) (0.4.6)
# Requirement already satisfied: webencodings in c:\users\laqua\appdata\local\programs\python\python312\lib\site-packages (from bleach->panel>=0.11.0->hvplot) (0.5.1)
# Requirement already satisfied: uc-micro-py in c:\users\laqua\appdata\local\programs\python\python312\lib\site-packages (from linkify-it-py->panel>=0.11.0->hvplot) (1.0.3)
# Requirement already satisfied: mdurl~=0.1 in c:\users\laqua\appdata\local\programs\python\python312\lib\site-packages (from markdown-it-py->panel>=0.11.0->hvplot) (0.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\laqua\appdata\local\programs\python\python312\lib\site-packages (from requests->panel>=0.11.0->hvplot) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\laqua\appdata\local\programs\python\python312\lib\site-packages (from requests->panel>=0.11.0->hvplot) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\laqua\appdata\local\programs\python\python312\lib\site-packages (from requests->panel>=0.11.0->hvplot) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\laqua\appdata\local\programs\python\python312\lib\site-packages (from requests->panel>=0.11.0->hvplot) (2024.7.4)
# %opts magic unavailable (pyparsing cannot be imported)
# %compositor magic unavailable (pyparsing cannot be imported)
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="c5bc631e-41f5-4bde-aed1-d77fdb1f2699" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"32de19fb-3a30-411d-824e-6cb87404e627":{"version":"3.4.3","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"p1002"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"p1003","attributes":{"plot_id":"p1002","comm_id":"55ea0c23ebf84dec912ead3dae219e7b","client_comm_id":"1393b10fcbf6468d9f15bbee85f0378b"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"fill","kind":"A ...
#   var render_items = [{"docid":"32de19fb-3a30-411d-824e-6cb87404e627","roots":{"p1002":"c5bc631e-41f5-4bde-aed1-d77fdb1f2699"},"root_ids":["p1002"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
# df = pd.read_csv('/content/Chicago.csv')

# %%
# cache data to improve dashboard performance
if 'data' not in pn.state.cache.keys():

    df = pd.read_csv("Chicago.csv")

    pn.state.cache['data'] = df.copy()

else:

    df = pn.state.cache['data']

# %%
df
# Out:
#     Geography Type  Year Geography  Population - Total  Population - Age 0-17  \
# 0         Citywide  2018   Chicago             2705988                 548999
# 1         ZIP Code  2018     60601               14675                    820
# 2         ZIP Code  2018     60602                1244                    149
# 3         ZIP Code  2018     60603                1174                     56
# 4         ZIP Code  2018     60604                 782                     38
# ..             ...   ...       ...                 ...                    ...
# 230       Zip Code  2021     60626               50295                   8007
# 231       Zip Code  2021     60628               64489                  13734
# 232       Zip Code  2021     60629              107487                  29283
# 233       Zip Code  2021     60630               55591                  11093
# 234       Zip Code  2021     60631               30589                   6925
#
#        Genz  Millennial  Population - Age 40-49    Genx  \
# 0    552935      456321                  336457  312965
# 1      4606        2792                    2190    1333
# 2       435         462                     135      53
# 3       561         101                      97     197
# 4       303         104                      51     101
# ..      ...         ...                     ...     ...
# 230   11937        8965                    6995    6738
# 231   11638        7491                    7593    9066
# 232   20690       13227                   14954   11096
# 233    7053        8926                    7337    7479
# 234    3308        4357                    3813    4657
#
#      Population - Age 60-69  ...  Population - Age 18+  Population - Age 65+  \
# 0                    262991  ...               2156989                349712
# 1                      1340  ...                 13855                  2075
# 2                        10  ...                  1095                     5
# 3                        97  ...                  1118                   112
# 4                       130  ...                   744                    93
# ..                      ...  ...                   ...                   ...
# 230                    4360  ...                 42288                  5098
# 231                    6930  ...                 50755                 10940
# 232                    8187  ...                 78204                 13746
# 233                    7975  ...                 44498                  9658
# 234                    3686  ...                 23664                  5546
#
#      Population - Female  Population - Male  Population - Latinx  \
# 0                1386113            1319875               776661
# 1                   7484               7191                 1274
# 2                    551                693                   81
# 3                    601                573                  115
# 4                    413                369                   34
# ..                   ...                ...                  ...
# 230                25318              24977                 9694
# 231                34961              29528                 2775
# 232                53753              53734                79111
# 233                27787              27804                14180
# 234                15516              15073                 4491
#
#      Population - Asian Non-Latinx  Population - Black Non-Latinx  \
# 0                         179841.0                       784266.0
# 1                              NaN                            NaN
# 2                              NaN                            NaN
# 3                              NaN                            NaN
# 4                              NaN                            NaN
# ..                             ...                            ...
# 230                         2724.0                        12646.0
# 231                           79.0                        59168.0
# 232                          595.0                        18878.0
# 233                         7122.0                         1007.0
# 234                         1262.0                          307.0
#
#      Population - White Non-Latinx  Population - Other Race Non-Latinx  \
# 0                           899980                            119467.0
# 1                             9677                                 NaN
# 2                              788                                 NaN
# 3                              707                                 NaN
# 4                              479                                 NaN
# ..                             ...                                 ...
# 230                          23029                              2202.0
# 231                           1462                              1005.0
# 232                           7650                              1253.0
# 233                          31325                              1957.0
# 234                          23360                              1169.0
#
#                  Record ID
# 0    Citywide-Chicago-2018
# 1      ZIP_Code-60601-2018
# 2      ZIP_Code-60602-2018
# 3      ZIP_Code-60603-2018
# 4      ZIP_Code-60604-2018
# ..                     ...
# 230    ZIP_CODE-60626-2021
# 231    ZIP_CODE-60628-2021
# 232    ZIP_CODE-60629-2021
# 233    ZIP_CODE-60630-2021
# 234    ZIP_CODE-60631-2021
#
# [235 rows x 26 columns]

# %% [markdown]
#   (0) Minor data processing

# %%
df['Geography'] = np.where(df['Geography'] == 'Citywide', '00000', df['Geography'])

# %%
# Make DataFrame Pipeline Interactive
df = df.interactive()

# %% [markdown]
#  (1) Population overtime by year & age

# %%
# Define Panel widgets
year_slider = pn.widgets.IntSlider(name='Year slider', start=2018, end=2021, step=1, value=2020)
year_slider
# Out:
# IntSlider(end=2021, name='Year slider', start=2018, value=2020)

# %%
# Radio buttons for Population Gen z Age measure
yaxis_Genz = pn.widgets.RadioButtonGroup(
    name='Y axis',
    options=['Genz','Genx','Millennial'],
    button_type='success',
  # Default selected value for demonstration
)

# %%
 (2) Population Tablw

# %%
Geography = ['60609','60635','60649','60624']
population_total_pipeline = (
    df[
(df['Year'] <= year_slider) &
        (df['Geography'].isin(Geography))  # Filter by Geography list
    ].groupby(['Geography', 'Year','Millennial','Genx'])[yaxis_population_total.value].mean()  # Group by 'Geography' and 'Year'
    .reset_index()  # Reset the index to include 'Geography' and 'Year' as columns
    .reset_index()
    .sort_values(by='Year')
    .reset_index(drop=True)
)
population_total_pipeline
# Out:
# <div id='ab19666f-421a-4fb3-abe8-11408f047ee5'>
#   <div id="b889aabe-eb6b-46c2-bb59-54daf8164e31" data-root-id="ab19666f-421a-4fb3-abe8-11408f047ee5" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {
}],"margin":0,"align":"start","children":[{"type":"object","name":"Slider","id":"f7f163de-63c6-4abf-a9a1-452eff636969","attributes":{"stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"id":"7f363b1d-1ee3-4c2e-b221-7af871f5c26f"},{"id":"9ddd8a7c-c5cf-4c56-bb82-784a548d7770"},{"type":"object","name":"ImportedStyleSheet","id":"17abfea3-3662-4fab-9440-8f2f3a8245cd","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.5/dist/bundled/theme/fast.css"}}],"margin":[5,10],"align":"start","title":"Year slider","start":2018,"end":2021,"value":2021}},{"type":"object","name":"panel.models.widgets.RadioButtonGroup","id":"67d025c3-bbd1-4933-ba9e-f44ba1db34d4","attributes":{"button_type":"success","css_classes":["solid"],"stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"id":"7f363b1d-1ee3-4c2e-b221-7af871f5c26f"},{"type":"object","name":"ImportedStyleSheet","id":"f85a71f8-1808-4195-b66a-15e27af3c05e","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.5/dist/css/button.css"}},{"id":"9ddd8a7c-c5cf-4c56-bb82-784a548d7770"},{"id":"17abfea3-3662-4fab-9440-8f2f3a8245cd"}],"margin":[5,10],"align":"start","labels":["Genz","Genx","Millennial"],"active":0}}]}},{"type":"object","name":"Figure","id":"11787e5c-be73-41ec-9f34-0b63bb0f9787","attributes":{"width":700,"height":300,"margin":[5,10],"sizing_mode":"fixed","align":"start","x_range":{"type":"object","name":"Range1d","id":"9f7c0be5-21e7-4bb1-aa1c-4bc8da6bf8ea","attributes":{"tags":[[["Year",null]],[]],"start":2017.8714285714286,"end":2021.12857142857 ...

# %% [markdown]
# (5) Barchart with Population Total Sources by Zip Code

# %%
yaxis_population_total_source = pn.widgets.RadioButtonGroup(
    name='Y axis',
    options=['Genx', 'Millennial','Genz'],
    button_type='success'
)

Geography_excl_world = ['60609', '60624', '60649','60635']

population_total_source_bar_pipeline = (
    df[
        (df['Year'] >= year_slider.value) &
        (df['Geography'].isin(Geography))  # Filter by Geography list
    ].groupby(['Geography','Genx','Millennial','Year','Genz' ])['Population - Total'].mean()  # Group by 'Geography' and 'Population_Age18-29', aggregate 'Population - Total'
    .reset_index()  # Reset the index
    .reset_index()
    .sort_values(by='Population - Total')
    .reset_index(drop=True)
)

# %%
population_total_source_bar_plot = population_total_source_bar_pipeline.hvplot(kind='bar',
                                                     x='Geography',
                                                     y=yaxis_population_total_source,
                                                     title='Population Age by Zipcode ')
population_total_source_bar_plot
# Out:
# <div id='f87eec1c-c396-4573-aed4-dd7a852f05ec'>
#   <div id="ec598d10-69d8-4236-922a-3db3c5cdd782" data-root-id="f87eec1c-c396-4573-aed4-dd7a852f05ec" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"8c136810-5d2f-4449-bb4a-81c43fb18739":{"version":"3.4.3","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"f87eec1c-c396-4573-aed4-dd7a852f05ec","attributes":{"name":"Row64918","stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"7c488cb6-790c-45f6-8207-fe7ae9c3eebb","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.5/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"e1061a22-ea13-48d3-848a-cc3e070c6fe8","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.5/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"93e4d331-4111-4f44-8264-980d424eefac","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.5/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":"43c33b96-657a-4bfd-986b-0c6c8e591c82","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.5/dist/bundled/theme/native.css"}}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"246c4142-3270-4cee-b671-02250be4afc3","attributes":{"name":"Column64917","stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"id":"7c488cb6-790c-45f6-8207-fe7ae9c3eebb"},{"id":"e1061a22-ea13-48d3-848a-cc3e070c6fe8"},{"id":"93e4d331-4111-4f44-8264-980d424eefac"},{"id":"43c33b96-657a-4bfd-986b-0c6c8e591c82"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"4d1e5bea-cdc1-417c-bc35-abdbf9ce3cd2","attributes":{"name":"Column64908","stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"id":"7c488cb6-790c-45f6-8207-fe7ae9c3eebb"},{"id":"e1061a22-ea13-48d3-848a-cc3e070c6fe8"},{"id":"93e4d331-4111-4f44-8264-980d424eefac"},{"id":"43c33b96-657a-4bfd-986b-0c6c8e591c82"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.widgets.RadioButtonGroup","id":"5417c896-0cfc-4ec3-9bd3-a27722e50bc5","attributes":{"button_type":"success","css_classes":["solid"],"stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"id":"7c488cb6-790c-45f6-8207-fe7ae9c3eebb"},{"type":"object","name":"ImportedStyleSheet","id":"f605f548-5894-457c-8abf-ec24a257992c","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.5/dist/css/button.css"}},{"id":"93e4d331-4111-4f44-8264-980d424eefac"},{"id":"43c33b96-657a-4bfd-986b-0c6c8e591c82"}],"margin":[5,10],"align":"start","labels":["Genx","Millennial","Genz"],"active":0}}]}},{"type":"object","name":"Figure","id":"536f4eee-3407-4a73-a0cc-d039042427ed","attributes":{"width":700,"height":300,"margin":[5,10],"sizing_mode":"fixed","align":"start","x_range":{"type":"object","name":"FactorRange","id":"ee200221-499d-4e93-a939-ea06da8bef64","attributes":{"tags":[[["Geography",null]],[]],"factors":["60624","60649","60609"]}},"y_range":{"type":"object","name":"Range1d","id":"26542000-68c5-4446-a840-e046b2b98bca","attributes":{"tags":[[["Genx",null]],{"type":"map","entries":[["invert_yaxis",false],["autorange",false]]}],"end":7886.5,"reset_start":0.0,"reset_end":7886.5}},"x_scale":{"type":"object","name":"CategoricalScale","id":"daa1a4ab-e657-4d8d-bec9-b0ebfd4e80b5"},"y_scale":{"type":"object","name":"LinearScale","id":"2c231cec-1ce0-40e8-8572-5ab8327247c8"},"title":{"type":"object","name":"Title","id":"44e68317-f797-40b0-a966-a49a8eacf743","attributes":{"text":"Population Age by Zipcode","text_color":"black","text_font_size":"12pt"}},"renderers":[{"type":"object ...

# %%
(6) Line graph with Population by Gender

# %%
# Radio buttons for gender measures
yaxis_gender = pn.widgets.RadioButtonGroup(
    name='Y axis', 
    options=['Population - Male', 'Population - Female', 'Population - Total'],
    button_type='success'
)
Year_excl_world = ['2018', '2019', '2020', '2021']


gender_pipeline = (
     df[
        (df['Year'] <= year_slider.value) &
        (df['Geography'].isin(Geography))  # Filter by Geography list
    ].groupby(['Year','Geography', 'Population - Male', 'Population - Female'])['Population - Total'].mean()  # Group by 'Geography' and 'Population_Age18-29', aggregate 'Population - Total'
    .reset_index()  # Reset the index
    .reset_index()
    .sort_values(by='Year')
    .reset_index(drop=True)
)

gender_pipeline
gender_plot = gender_pipeline.hvplot(x = 'Year', by = 'Geography', y=yaxis_gender,line_width=2, title="Gender by Population")
gender_plot
# Out:
# <div id='d01a2c14-30e1-409d-84d9-f072a13cd01c'>
#   <div id="cda8ccd2-5e9b-4ba8-8492-45536e8a73dc" data-root-id="d01a2c14-30e1-409d-84d9-f072a13cd01c" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"f0980094-3248-4885-affb-68d6d1ed495d":{"version":"3.4.3","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"d01a2c14-30e1-409d-84d9-f072a13cd01c","attributes":{"name":"Row46978","stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"762cbbcd-b465-4a4c-97d9-1b48f76e5235","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.5/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"7a4223be-a932-428d-b3cc-16af66584958","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.5/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"b24421ea-81b3-4945-b26c-2a4fe7b4e53c","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.5/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":"f7ef0397-551b-46da-8a07-21cc3a39b098","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.5/dist/bundled/theme/native.css"}}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"0caba852-1414-44cb-9aaf-61b5bb2ae9f8","attributes":{"name":"Column46977","stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"id":"762cbbcd-b465-4a4c-97d9-1b48f76e5235"},{"id":"7a4223be-a932-428d-b3cc-16af66584958"},{"id":"b24421ea-81b3-4945-b26c-2a4fe7b4e53c"},{"id":"f7ef0397-551b-46da-8a07-21cc3a39b098"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"0008cb03-f0ef-4af2-8d56-c92484c710a9","attributes":{"name":"Column46968","stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"id":"762cbbcd-b465-4a4c-97d9-1b48f76e5235"},{"id":"7a4223be-a932-428d-b3cc-16af66584958"},{"id":"b24421ea-81b3-4945-b26c-2a4fe7b4e53c"},{"id":"f7ef0397-551b-46da-8a07-21cc3a39b098"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.widgets.RadioButtonGroup","id":"e4b4aa74-a620-4490-b45e-ae1c900c452e","attributes":{"button_type":"success","css_classes":["solid"],"stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"id":"762cbbcd-b465-4a4c-97d9-1b48f76e5235"},{"type":"object","name":"ImportedStyleSheet","id":"9af113a2-8b09-4ff0-8103-c58a73b2a741","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.5/dist/css/button.css"}},{"id":"b24421ea-81b3-4945-b26c-2a4fe7b4e53c"},{"id":"f7ef0397-551b-46da-8a07-21cc3a39b098"}],"margin":[5,10],"align":"start","labels":["Population - Male","Population - Female","Population - Total"],"active":0}}]}},{"type":"object","name":"Figure","id":"a5bbb9a0-d813-4cbf-94a3-904a2f75392d","attributes":{"width":700,"height":300,"margin":[5,10],"sizing_mode":"fixed","align":"start","x_range":{"type":"object","name":"Range1d","id":"12c8b105-cf9d-4a38-90b8-fea0dd24a815","attributes":{"tags":[[["Year",null]],[]],"start":2018.0,"end":2021.0,"reset_start":2018.0,"reset_end":2021.0}},"y_range":{"type":"object","name":"Range1d","id":"e19715e5-3b28-46fc-a50d-9b1421478e03","attributes":{"tags":[[["Population - Male",null]],{"type":"map","entries":[["invert_yaxis",false],["autorange",false]]}],"start":15113.0,"end":32333.0,"reset_start":15113.0,"reset_end":32333.0}},"x_scale":{"type":"object","name":"LinearScale","id":"28d6eef4-d822-462c-9327-e628c40712bd"},"y_scale":{"type":"object","name":"LinearScale","id":"be33aa27-3fd1-40bc-9a88-c20322ab8e1c"},"title":{"type":"object","name":"Title","id":"46f7c42a-8e79-4a0d-b66b-112cc03c0865","attributes":{"text":"Gender by Pop ...

# %% [markdown]
# #Creating Dashboard

# %%
#Layout using Template
template = pn.template.FastListTemplate(
    title='Chicago Population dashboard',
    sidebar=[pn.pane.Markdown("# Chicago Facts"),
             pn.pane.Markdown("#### Chicago is the third largest city in the united states with over 3 million people living there. As of 2020, Chicago's population was 2,746,388. The city's population peaked in 1950 at 3,621,092, but has since declined.For every 100 females in Chicago, there are 94.2 males.Chicago's population is also broken down by age group: 26.2% are under 18, 11.2% are 18–24, 33.4% are 25–44, 18.9% are 45–64, and 10.3% are 65 and older. The median age is 32."),
             pn.pane.PNG('Chicago Skyline.png', sizing_mode='scale_both'),
             pn.pane.Markdown("## Settings"), year_slider],
        main=[pn.Row(pn.Column( yaxis_Genz,
                           Population_plot.panel(width=700), margin=(0,25)),
                 Population_table.panel(width=500)),
          pn.Row(pn.Column(yaxis_gender, gender_plot.panel(width=600)),
              pn.Column(yaxis_population_total_source, population_total_source_bar_plot.panel(width=600)))],
    accent_base_color="#88d8b0",
    header_background="#88d8b0",
)
# template.show()
template.show();
# Out:
# Launching server at http://localhost:49733
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='420257b7-ee19-425c-b350-72c7437c0a67', ...)
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='94901a56-05c7-499a-8e2c-05dbc2f860ab', ...)
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='a14ebef6-ead8-4f04-9467-5b84e120a578', ...)
